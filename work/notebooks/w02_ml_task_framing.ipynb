# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mannamamulya/flyrank-intern/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Lane: Train and compare the model (ML-08)
#
# This lane is a classification problem. The goal is to classify whether a content page is likely to decline in search performance or not. The model predicts which pages should be prioritized for review, helping SEO teams focus on the pages that are most likely to need updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is whether a content page is declining in search performance. In the starter dataset, I use the trend_direction column as the target. Pages with trend_direction = "down" are labeled as declining, while all other pages are labeled as not declining. In the starter dataset this label is defined from the observed trend percentage, so it is suitable for learning the workflow, but future work should use a label measured in a later time window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining"] = (df["trend_direction"] == "down").astype(int)

df[["trend_direction", "is_declining"]].head()
# Out:
#   trend_direction  is_declining
# 0            down             1
# 1            down             1
# 2            down             1
# 3          stable             0
# 4            down             1

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# The success metric is Precision@50. This measures how many of the top 50 pages recommended by the model are actually declining. A higher Precision@50 means the recommendations are more useful because content teams spend their time reviewing the right pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Declining pages:", df["is_declining"].sum())
print("Total pages:", len(df))
print("Declining rate:", round(df["is_declining"].mean(), 3))
# Out:
# Declining pages: 16262
# Total pages: 30000
# Declining rate: 0.542

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one content page. Each row in the dataset represents a single content item with features such as impressions, click-through rate, average position, engagement, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

unit_df = df[[
    "content_id",
    "client_id",
    "impressions_90d",
    "avg_position",
    "ctr",
    "trend_direction",
    "is_declining"
]]

display(unit_df.head())
# Out:
# Rows: 30000
# Columns: 45
#              content_id          client_id  impressions_90d  avg_position  \
# 0  content_304f48230142  client_f369cb89fc             3803          10.6
# 1  content_a1fb4e703a9e  client_4e07408562            15320          20.3
# 2  content_9aa793d4d895  client_7f2253d7e2            12581          36.5
# 3  content_331d6c4de07b  client_19581e27de            11751           6.2
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140          44.0
#
#     ctr trend_direction  is_declining
# 0  0.76            down             1
# 1  0.05            down             1
# 2  0.09            down             1
# 3  0.49          stable             0
# 4  0.13            down             1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule usually relies on one or two conditions, such as pages with many impressions or pages that have not been updated recently. However, search performance depends on many factors working together, including impressions, rankings, CTR, engagement, and content characteristics. A machine learning model can learn these patterns from historical data and provide better decision support than a simple hand-written rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
