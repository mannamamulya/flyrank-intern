# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mannamamulya/flyrank-intern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane (or freestyle) and why
# **Lane:** Train and compare the model (ML-08)
#
# I chose this lane because I want to investigate whether machine learning can help identify content that is likely to decline in search performance. Comparing different models will help determine which approach provides better decision support for prioritizing content updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The question: decision, action, cost of a wrong call
#
# This project improves the decision of which content pages should be reviewed or refreshed first.
#
# The output will be used by SEO managers or content strategists to prioritize pages that are most likely to decline in performance.
#
# A false positive wastes time reviewing pages that do not require updates, while a false negative may miss pages that are actually declining, leading to reduced traffic and missed opportunities.

# %%
import pandas as pd

# Assuming your starter CSV is named 'starter.csv' or similar.
# You might need to adjust the path or filename based on your actual data location.
df = pd.read_csv('/content/sample_data/california_housing_train.csv') # Placeholder: replace with your actual CSV path

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# The 'client_id' column is not in this sample dataset. Please use a column present in your actual starter CSV.
# For example, if 'total_rooms' could represent a unique identifier, you could use:
# print("Unique total_rooms:", df["total_rooms"].nunique())
# Out:
# Rows: 17000
# Columns: 9

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data (2–3 real numbers)
#
# The starter dataset contains **30,000 rows** and **44 columns** collected from **32 anonymized clients**. The dataset also contains missing values that will require careful handling during later analysis. For example, **provider_used** has **21,438** missing values, while **word_count** and **char_count** each have **7,699** missing values.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Unique clients:", df["client_id"].nunique())

print("\nTop 5 missing values:")
print(df.isnull().sum().sort_values(ascending=False).head())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words: what I can and can't claim
#
# This project can identify observed relationships between historical content features and content performance. The results can provide decision support for prioritizing which content pages may need review or updates.
#
# The project cannot prove that one feature causes better or worse search performance. It also cannot predict Google's ranking algorithm or guarantee future performance. Any conclusions are limited to the available dataset and should be interpreted as observed patterns rather than causal relationships.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
